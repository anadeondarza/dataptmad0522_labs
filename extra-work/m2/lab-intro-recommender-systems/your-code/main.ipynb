# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/dataptmad0522_labs/extra-work/m2/lab-intro-recommender-systems/data/customer_product_sales.csv')

# %%
data
# Out:
#        CustomerID FirstName   LastName  SalesID  ProductID  \
# 0           61288      Rosa   Andersen   134196        229
# 1           77352     Myron     Murray  6167892        229
# 2           40094     Susan  Stevenson  5970885        229
# 3           23548    Tricia    Vincent  6426954        229
# 4           78981     Scott      Burch   819094        229
# ...           ...       ...        ...      ...        ...
# 68579       94547    Gerald    Donovan   687884        211
# 68580       57654  Lashonda        Roy  4373415        211
# 68581       36751      Glen  Frederick  2405597        211
# 68582       43270     Devon  Mc Daniel  4328852        211
# 68583       78718     Mandy     Abbott  6175098        211
#
#                          ProductName  Quantity
# 0               Bread - Hot Dog Buns        16
# 1               Bread - Hot Dog Buns        20
# 2               Bread - Hot Dog Buns        11
# 3               Bread - Hot Dog Buns         6
# ...

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
data['ProductID'].value_counts()
# Out:
# 29     186
# 222    182
# 396    181
# 123    181
# 273    180
#       ...
# 229    120
# 9      119
# 16     119
# 444    119
# 317    109
# Name: ProductID, Length: 452, dtype: int64

# %%
data['ProductName'].value_counts()
# Out:
# Spinach - Baby                      186
# Sole - Dover, Whole, Fresh          182
# Tea - Jasmin Green                  181
# Oil - Shortening - All - Purpose    181
# Bandage - Flexible Neon             180
#                                    ...
# Bread - Hot Dog Buns                120
# Rabbit - Whole                      119
# Kellogs Special K Cereal            119
# Cheese - Cambozola                  119
# Water - Green Tea Refresher         109
# Name: ProductName, Length: 452, dtype: int64

# %%
data_1  = data.groupby(by=['CustomerID', 'ProductName'], as_index=False)[['Quantity']].sum()#.reset_index()
data_1
# Out:
#        CustomerID                    ProductName  Quantity
# 0              33               Apricots - Dried         1
# 1              33              Assorted Desserts         1
# 2              33        Bandage - Flexible Neon         1
# 3              33  Bar Mix - Pina Colada, 355 Ml         1
# 4              33         Beans - Kidney, Canned         1
# ...           ...                            ...       ...
# 63623       98200                   Vol Au Vents        50
# 63624       98200                  Wasabi Powder        25
# 63625       98200       Wine - Fume Blanc Fetzer        25
# 63626       98200  Wine - Hardys Bankside Shiraz        25
# 63627       98200        Yogurt - French Vanilla        25
#
# [63628 rows x 3 columns]

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
dataset1 = pd.pivot_table(data_1, columns = data_1.index)
newdf = dataset1.fillna(0)
newdf
# Out:
#             0      1      2      3      4      5      6      7      8      \
# CustomerID     33     33     33     33     33     33     33     33     33
# Quantity        1      1      1      1      1      1      1      1      1
#
#             9      ...  63618  63619  63620  63621  63622  63623  63624  \
# CustomerID     33  ...  98200  98200  98200  98200  98200  98200  98200
# Quantity        1  ...     25     25     25     25     25     50     25
#
#             63625  63626  63627
# CustomerID  98200  98200  98200
# Quantity       25     25     25
#
# [2 rows x 63628 columns]

# %%
data_2 = pd.pivot_table(data_1, values='Quantity', columns='CustomerID', index='ProductName', fill_value=0)
data_2 = data_2.transpose()
data_2
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                                   0                                  0
# 200                                  0                                  0
# 264                                  0                                  0
# 356                                  0                                  0
# 412                                  0                                  0
# ...                                ...                                ...
# 97928                                0                                  0
# 98069                                0                                  0
# 98159                                0                                  0
# 98185                                0                                  0
# 98200                                0                                  0
#
# ...

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
dist_calculation = pdist(X=data_2, metric='euclidean')
dist_calculation
# Out:
# array([ 11.91637529,  10.48808848,  11.22497216, ..., 304.13812651,
#        305.16389039, 303.10889132])

# %%
dist_distribution = squareform(dist_calculation)
dist_distribution
# Out:
# array([[  0.        ,  11.91637529,  10.48808848, ..., 228.62851966,
#         239.        , 229.77380181],
#        [ 11.91637529,   0.        ,  11.74734012, ..., 228.01096465,
#         239.03765394, 229.70415756],
#        [ 10.48808848,  11.74734012,   0.        , ..., 228.08112592,
#         238.26665734, 229.77380181],
#        ...,
#        [228.62851966, 228.01096465, 228.08112592, ...,   0.        ,
#         304.13812651, 305.16389039],
#        [239.        , 239.03765394, 238.26665734, ..., 304.13812651,
#           0.        , 303.10889132],
#        [229.77380181, 229.70415756, 229.77380181, ..., 305.16389039,
#         303.10889132,   0.        ]])

# %%
euclid_dist = pd.DataFrame(dist_distribution,
                           index=data_2.index, 
                           columns=data_2.index)

euclid_dist
# Out:
# CustomerID       33          200         264         356         412    \
# CustomerID
# 33            0.000000   11.916375   10.488088   11.224972   11.401754
# 200          11.916375    0.000000   11.747340   12.083046   12.569805
# 264          10.488088   11.747340    0.000000   11.489125   11.224972
# 356          11.224972   12.083046   11.489125    0.000000   12.083046
# 412          11.401754   12.569805   11.224972   12.083046    0.000000
# ...                ...         ...         ...         ...         ...
# 97928       220.501701  220.202180  219.136943  219.952268  219.733930
# 98069       217.188858  215.728997  216.612557  217.437347  217.446545
# 98159       228.628520  228.010965  228.081126  228.098663  227.997807
# 98185       239.000000  239.037654  238.266657  238.493186  238.396728
# 98200       229.773802  229.704158  229.773802  229.464594  228.927936
#
# CustomerID       464         477         639         649         669    ...  \
# ...

# %%
euclid_dist_norm = pd.DataFrame(1/(1 + squareform(pdist(data_2, 'euclidean'))),
                                index=data_2.index, 
                                columns=data_2.index)

euclid_dist_norm
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.077421  0.087047  0.081800  0.080634  0.082709
# 200         0.077421  1.000000  0.078448  0.076435  0.073693  0.075255
# 264         0.087047  0.078448  1.000000  0.080070  0.081800  0.080350
# 356         0.081800  0.076435  0.080070  1.000000  0.076435  0.078187
# 412         0.080634  0.073693  0.081800  0.076435  1.000000  0.078711
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.004515  0.004521  0.004543  0.004526  0.004530  0.004533
# 98069       0.004583  0.004614  0.004595  0.004578  0.004578  0.004578
# 98159       0.004355  0.004367  0.004365  0.004365  0.004367  0.004363
# 98185       0.004167  0.004166  0.004179  0.004175  0.004177  0.004167
# 98200       0.004333  0.004335  0.004333  0.004339  0.004349  0.004347
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# ...

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
euclid_simil_norm = euclid_dist_norm[356].sort_values(ascending=False)[1:]
eu_list = euclid_simil_norm.head(5)
eu_list
#para cada ID habría que realizarlo
# Out:
# CustomerID
# 3317    0.085638
# 1008    0.085297
# 3253    0.084297
# 3305    0.084297
# 2503    0.083333
# Name: 356, dtype: float64

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
data_select = data_1[data_1['CustomerID'].isin(eu_list.index)]
data_select
# Out:
#       CustomerID                        ProductName  Quantity
# 887         1008                    Banana - Leaves         1
# 888         1008  Bar - Granola Trail Mix Fruit Nut         1
# 889         1008                Beef - Inside Round         1
# 890         1008                 Beef - Top Sirloin         1
# 891         1008                 Beer - Labatt Blue         1
# ...          ...                                ...       ...
# 2835        3317                       Vol Au Vents         1
# 2836        3317      Wine - Ej Gallo Sierra Valley         1
# 2837        3317         Wine - Magnotta - Belpaese         1
# 2838        3317      Wine - Wyndham Estate Bin 777         1
# 2839        3317                    Wonton Wrappers         1
#
# [266 rows x 3 columns]

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
data_agg = data_select.groupby(by = ['ProductName'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
data_agg
# Out:
#                        ProductName  Quantity
# 30               Butter - Unsalted         5
# 190          Veal - Inside, Choice         4
# 200  Wine - Blue Nun Qualitatswein         3
# 176        Table Cloth 81x81 White         3
# 193              Veal - Sweetbread         3
# ..                             ...       ...
# 82                     Fuji Apples         1
# 83            Garbage Bags - Clear         1
# 84        Gatorade - Xfactor Berry         1
# 85   Gloves - Goldtouch Disposable         1
# 217              Zucchini - Yellow         1
#
# [218 rows x 2 columns]

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
#MERGE ON the comun column 
data_transpose = data_2.transpose()
data_transpose
# Out:
# CustomerID                         33     200    264    356    412    464    \
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0      0      0      0
# Apricots - Dried                       1      0      0      0      1      0
# ...                                  ...    ...    ...    ...    ...    ...
# Yeast Dry - Fermipan                   0      0      0      0      0      0
# Yoghurt Tubes                          0      0      0      0      0      0
# Yogurt - Blueberry, 175 Gr             0      1      0      0      0      0
# Yogurt - French Vanilla                1      0      0      1      0      0
# Zucchini - Yellow                      0      0      0      0      0      0
#
# ...

# %%
d_merge = data_transpose.merge(data_agg, on='ProductName')
d_merge
# Out:
#                        ProductName  33  200  264  356  412  464  477  639  \
# 0        Appetizer - Mushroom Tart   0    0    0    0    0    0    0    1
# 1        Appetizer - Sausage Rolls   0    0    0    0    0    0    0    0
# 2                  Banana - Leaves   0    0    1    0    1    1    0    0
# 3            Bandage - Fexible 1x3   0    0    0    0    0    0    0    0
# 4          Bandage - Flexible Neon   1    0    1    0    0    0    0    0
# ..                             ...  ..  ...  ...  ...  ...  ...  ...  ...
# 213  Wine - Wyndham Estate Bin 777   0    0    1    0    1    1    0    0
# 214                Wonton Wrappers   0    0    0    0    0    0    1    0
# 215                  Yoghurt Tubes   0    0    0    0    0    0    0    0
# 216        Yogurt - French Vanilla   1    0    0    1    0    0    2    0
# 217              Zucchini - Yellow   0    0    0    0    0    0    0    0
#
#      649  ...  97753  97769  97793  97900  97928  98069  98159  98185  98200  \
# ...

# %%
#Filter for records where the chosen customer has not purchased the product.
#chosen costumer 356

rslt_df = d_merge.loc[d_merge[356] == 0]  
rslt_df
# Out:
#                           ProductName  33  200  264  356  412  464  477  639  \
# 0           Appetizer - Mushroom Tart   0    0    0    0    0    0    0    1
# 1           Appetizer - Sausage Rolls   0    0    0    0    0    0    0    0
# 2                     Banana - Leaves   0    0    1    0    1    1    0    0
# 3               Bandage - Fexible 1x3   0    0    0    0    0    0    0    0
# 4             Bandage - Flexible Neon   1    0    1    0    0    0    0    0
# ..                                ...  ..  ...  ...  ...  ...  ...  ...  ...
# 212  Wine - White, Schroder And Schyl   0    0    0    0    1    0    0    0
# 213     Wine - Wyndham Estate Bin 777   0    0    1    0    1    1    0    0
# 214                   Wonton Wrappers   0    0    0    0    0    0    1    0
# 215                     Yoghurt Tubes   0    0    0    0    0    0    0    0
# 217                 Zucchini - Yellow   0    0    0    0    0    0    0    0
#
# ...

# %%
df_final = rslt_df.loc[:, ['ProductName', 356, 'Quantity']].sort_values(by='Quantity', ascending=False)
df_final.head(5)
# le recomendamos al CostumerID 356 esos 5 productos que no ha comprado ordenador por quiantity más comprada
#de otros costumbers
# Out:
#                      ProductName  356  Quantity
# 30             Butter - Unsalted    0         5
# 190        Veal - Inside, Choice    0         4
# 108       Nut - Chestnuts, Whole    0         3
# 20   Beets - Candy Cane, Organic    0         3
# 143          Raspberries - Fresh    0         2

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
#debajo del lopp metemos todos los pasos anteriores. Debido a alguna forma de realizarlos, no es reproducible, 
#pero no sabría hacerlo de otra forma. 
dict_fi = {}
list_fi = []


for id_c in data['CustomerID'].unique():
    euclid_simil_norm = euclid_dist_norm[356].sort_values(ascending=False)[1:]    
    eu_list = euclid_simil_norm.tolist()
    data_select = data_1[data_1['CustomerID'].isin(eu_list.index)]
    data_agg = data_select.groupby(by = ['ProductName'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
    data_transpose = data_2.transpose()
    d_merge = data_transpose.merge(data_agg, on='ProductName')
    rslt_df = d_merge.loc[d_merge[356] == 0]  
    df_final = rslt_df.loc[:, ['ProductName', 356, 'Quantity']].sort_values(by='Quantity', ascending=False)
    list_fi.append(df_final)

dict_fi = dict(data_1['CustomerID'].unique(), list_fi)

dict_fi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 7>()
#       8 euclid_simil_norm = euclid_dist_norm[356].sort_values(ascending=False)[1:]
#       9 eu_list = euclid_simil_norm.tolist()
# ---> 10 data_select = data_1[data_1['CustomerID'].isin(eu_list.index)]
#      11 data_agg = data_select.groupby(by = ['ProductName'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
#      12 data_transpose = data_2.transpose()
#
# File ~/miniconda3/envs/jp_env/lib/python3.9/site-packages/pandas/core/series.py:5141, in Series.isin(self, values)
#    5068 def isin(self, values) -> Series:
#    5069     """
#    5070     Whether elements in Series are contained in `values`.
#    5071
#    (...)
#    5139     dtype: bool
#    5140     """
# -> 5141     result = algorithms.isin(self._values, values)
# ...

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
df = pd.DataFrame(list_fi)
df

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
data_t = data_2.T
data_cos_norm = pd.DataFrame(1/(1 + squareform(pdist(data_t, 'cosine'))),
                                index=data_2.columns,
                                columns=data_2.columns)

# %%
#creamos un lopp que pase por todos los pasos anteriores on le medida cosine!
dict_f = {}
list_f = []


for id_c in data['CustomerID'].unique():
    data_cos_norm_si = data_cos_norm[id_c].sort_values(ascending=False)[1:]
    list_list = data_cos_norm_si.tolist()
    data_select_list = data_1[data_1['CustomerID'].isin(list_list.index)]
    data_agg_cosine = data_select_list.groupby(by = ['ProductName'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
    data_transpose = data_2.transpose()
    d_merge_cosine = data_transpose.merge(data_agg_cosine, on='ProductName')
    rslt_df_cosine = d_merge_cosinee.loc[d_merge[id_c] == 0] 
    df_final_cosine = rslt_df_cosine.loc[:, ['ProductName', id_c, 'Quantity']].sort_values(by='Quantity', ascending=False)
    listf_f.append(df_final_cosine)

dict_f = dict(data_1['CustomerID'].unique(), list_f)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/jp_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniconda3/envs/jp_env/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/jp_env/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 61288
#
# The above exception was the direct cause of the following exception:
#
# ...
